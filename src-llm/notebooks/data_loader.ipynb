# %%
import pandas as pd

train = pd.read_parquet('../../data/train/train-00000-of-00001.parquet',columns=['question','query'])

train_sample = train.sample(frac=0.1).reset_index(drop=True)

# train_sample.drop('source', axis=1,inplace=True)

train_sample
# Out:
#                                               question  \
# 0    Find the name and budget of departments whose ...
# 1    Which building does the instructor who teaches...
# 2    Which country does customer with first name as...
# 3    Show the names of products that are in at leas...
# 4                          Count the number of actors.
# ..                                                 ...
# 695  What is the name of the game that has been pla...
# 696  Find the maximum and minimum monthly rental fo...
# 697  Find each target user's name and average trust...
# 698  For the oldest movie listed, what is its avera...
# 699  What are the drivers' first names,last names, ...
#
#                                                  query
# 0    SELECT dept_name ,  budget FROM department WHE...
# 1    SELECT T2.Building FROM COURSE AS T1 JOIN FACU...
# 2    SELECT T2.country FROM Customers AS T1 JOIN Ad...
# 3    SELECT T1.Product_Name FROM Products AS T1 JOI...
# 4                           SELECT count(*) FROM actor
# ..                                                 ...
# 695  SELECT gname FROM Plays_games AS T1 JOIN Video...
# 696  SELECT max(monthly_rental) ,  min(monthly_rent...
# 697  SELECT T1.name ,  avg(trust) FROM useracct AS ...
# 698  SELECT avg(T1.stars) ,  T2.title FROM Rating A...
# 699  SELECT T1.forename ,  T1.surname ,  T1.driveri...
#
# [700 rows x 2 columns]

# %%
with open('instructions.txt', 'w') as file:
    for idx, row in train_sample.iterrows():
        file.write(f"question {row['question']}\n")
        file.write(f"query {row['query']}\n")
        file.write('\n')
